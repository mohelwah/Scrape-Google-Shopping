# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
           }

company_link = 'https://www.linkedin.com/voyager/api/entities/companies/76137283'

with requests.session() as s:
    s.cookies['li_at'] = "AQEIACMHPkMvrgOYvEsAAAGDcP1DJgAAAYOVCccmTQAAAAAAAAAAADBGAiEAkKeC2zquafqzLpZ1Im6apVaD9-QCDORTvuwr7hQJpRUCIQCGhYoH0fRASHYQ1rDmDXIbrONVtu3h1BwIDGvPh66iBn7nAiXLYzCb0XOUmFxbMjQl8fVy"
    s.cookies["JSESSIONID"] = "ajax:8343847006655895677"
    s.headers = headers
    s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
    response = s.get(company_link)
    response_dict = response.json()
    print(response_dict)
# Out:
# {'employeeCountRange': 'myself only', 'entityUrn': 'urn:li:fs_company:76137283', 'websiteUrl': 'http://www.thechemistryofcopy.com', 'companyType': 'Self Employed', 'entityInfo': {'objectUrn': 'urn:li:company:76137283', 'trackingId': 'UTXio/NyT/K8GOJwVbqwCw=='}, 'industries': ['Marketing and Advertising'], 'description': 'Copywriting - I write for websites, email, adverts, brochures, leaflets and more to get the benefits of you and your business to your ideal target audience.\n\nCoaching - I teach you all you need to know so that you can write effectively for your business. Great for those just starting out or those who want to keep things in house.', 'basicCompanyInfo': {'headquarters': 'Cheshire', 'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:76137283', 'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:76137283', 'following': False, 'trackingUrn': 'urn:li:company:76137283', 'followingType': 'DEFAULT'}, 'miniCompany': {'objectUrn': 'urn:l
# ...

# %%
li_at = "AQEIACMHPkMvrgOYvEsAAAGDcP1DJgAAAYOVCccmTQAAAAAAAAAAADBGAiEAkKeC2zquafqzLpZ1Im6apVaD9-QCDORTvuwr7hQJpRUCIQCGhYoH0fRASHYQ1rDmDXIbrONVtu3h1BwIDGvPh66iBn7nAiXLYzCb0XOUmFxbMjQl8fVy"

# %%
JSESSIONID = "ajax:8343847006655895677"

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36 Edg/105.0.1343.27",
           }

company_link = search

with requests.session() as s:
    s.cookies['li_at'] = li_at
    s.cookies["JSESSIONID"] = JSESSIONID
    s.headers = headers
    s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
    response = s.get(company_link)
    response_dict = response.json()
    print(response_dict)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-57-56f2a4403148> in <module>
#      11     s.headers = headers
#      12     s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
# ---> 13     response = s.get(company_link)
#      14     response_dict = response.json()
#      15     print(response_dict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
# ...

# %%
linkedin  = "www.linkedin.com"

# %%
path="/voyager/api/search/dash/clusters?decorationId=com.linkedin.voyager.dash.deco.search.SearchClusterCollection-162&origin=FACETED_SEARCH&q=all&query=(keywords:crypto%20,flagshipSearchIntent:SEARCH_SRP,queryParameters:(companyHqGeo:List(101165590),resultType:List(COMPANIES)),includeFiltersInResponse:false)&start=60"

# %%
search = linkedin+path
search
# Out:
# 'www.linkedin.com/voyager/api/search/dash/clusters?decorationId=com.linkedin.voyager.dash.deco.search.SearchClusterCollection-162&origin=FACETED_SEARCH&q=all&query=(keywords:crypto%20,flagshipSearchIntent:SEARCH_SRP,queryParameters:(companyHqGeo:List(101165590),resultType:List(COMPANIES)),includeFiltersInResponse:false)&start=60'

# %%
import requests
headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
           }

link = search
with requests.session() as s:
    s.cookies['li_at'] = li_at
    s.cookies["JSESSIONID"] = JSESSIONID
    s.headers = headers
    s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
    response = s.get(link)
    response_dict = response.json()
    print(response_dict)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-53-1b836e4828e2> in <module>
#       9     s.headers = headers
#      10     s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
# ---> 11     response = s.get(link)
#      12     response_dict = response.json()
#      13     print(response_dict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# ...

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
           }

company_link = "https://www.linkedin.com/voyager/api/search/dash/clusters?decorationId=com.linkedin.voyager.dash.deco.search.SearchClusterCollection-162&origin=FACETED_SEARCH&q=all&query=(keywords:chemistry,flagshipSearchIntent:SEARCH_SRP,queryParameters:(companyHqGeo:List(101165590),resultType:List(COMPANIES)),includeFiltersInResponse:false)&start=20"
with requests.session() as s:
    s.cookies['li_at'] = "AQEIACMHPkMvrgOYvEsAAAGDcP1DJgAAAYOVCccmTQAAAAAAAAAAADBGAiEAkKeC2zquafqzLpZ1Im6apVaD9-QCDORTvuwr7hQJpRUCIQCGhYoH0fRASHYQ1rDmDXIbrONVtu3h1BwIDGvPh66iBn7nAiXLYzCb0XOUmFxbMjQl8fVy"
    s.cookies["JSESSIONID"] = "ajax:8343847006655895677"
    s.headers = headers
    s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
    response = s.get(company_link)
    response_dict1 = response.json()
    print(response_dict1)
# Out:
# {'metadata': {'primaryResultType': 'COMPANIES', 'blockedQuery': False, 'searchId': 'c57fb036-2e5a-4c26-ab20-52dc86700bf0', 'filterAppliedCount': 0, 'totalResultCount': 1430, '$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterCollectionMetadata'}, 'elements': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterViewModel', 'position': 21, 'results': [{'trackingUrn': 'urn:li:company:76137283', 'primaryActions': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.EntityAction', 'actionDetails': {'followAction': {'entityUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:76137283', 'following': False, 'preDashFollowingInfoUrn': 'urn:li:fs_followingInfo:urn:li:company:76137283', '$recipeType': 'com.linkedin.voyager.dash.deco.search.FollowingState', 'followerCount': 77}}, 'actionDetailsUnion': {'followAction': 'urn:li:fsd_followingState:urn:li:fsd_company:76137283'}}], 'title': {'textDirection': 'USER_LOCALE', '$recipeType': 'com.linkedin.voyager.dash.de
# ...

# %%
response_dict1
# Out:
# {'metadata': {'primaryResultType': 'PEOPLE',
#   'blockedQuery': False,
#   'searchId': '4baf8bbd-cc44-4718-bb93-800b16647aa1',
#   'filterAppliedCount': 0,
#   'totalResultCount': 3841842,
#   '$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterCollectionMetadata',
#   'queryType': 'EXPLORE'},
#  'elements': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterViewModel',
#    'position': 21,
#    'results': [{'image': {'attributes': [{'$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageAttribute',
#         'detailDataUnion': {'profilePicture': 'urn:li:fsd_profile:ACr___rwJFABhpWg_rAyelBDZ415PoQsQ8T-waM'}}],
#       '$recipeType': 'com.linkedin.voyager.dash.deco.common.image.ImageViewModel'},
#      'secondarySubtitle': {'textDirection': 'USER_LOCALE',
#       '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#       'text': 'Cairo, Egypt',
#       'attributesV2': []},
# ...

# %%
## get list of companies
companies= []
for i in response_dict1['elements']: 
    for z in i['results']:
        for j in z.values():
            companies.append(j.split(sep=":")[-1])
            print(j.split(sep=":")[-1])
            break
# Out:
# 78315544
# 33246841
# 20711642
# 77016880
# 72452156
# 11821896
# 77914098
# 18543840
# 74030662
# 18881550

# %%
companies
# Out:
# ['78315544']

# %%
for i in sub['results']:
    for j in i.values():
        print(j)
        break
# Out:
# urn:li:company:79148173
# urn:li:company:18573594
# urn:li:company:13455953
# urn:li:company:17949672
# urn:li:company:70457597
# urn:li:company:75057736
# urn:li:company:11211633
# urn:li:company:18807806
# urn:li:company:78999795
# urn:li:company:47654576

# %%
response_dict1
# Out:
# {'metadata': {'primaryResultType': 'COMPANIES',
#   'blockedQuery': False,
#   'searchId': 'edb0c445-7837-4d4f-b3d2-03942c197d2e',
#   'filterAppliedCount': 0,
#   'totalResultCount': 2630,
#   '$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterCollectionMetadata'},
#  'elements': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterViewModel',
#    'position': 11,
#    'results': [{'trackingUrn': 'urn:li:company:79148173',
#      'primaryActions': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.EntityAction',
#        'actionDetails': {'followAction': {'entityUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:79148173',
#          'following': False,
#          'preDashFollowingInfoUrn': 'urn:li:fs_followingInfo:urn:li:company:79148173',
#          '$recipeType': 'com.linkedin.voyager.dash.deco.search.FollowingState',
#          'followerCount': 94}},
# ...

# %%
companies
# Out:
# ['79148173',
#  '18573594',
#  '13455953',
#  '17949672',
#  '70457597',
#  '75057736',
#  '11211633',
#  '18807806',
#  '78999795',
#  '47654576']

# %%
company_link = 'https://www.linkedin.com/voyager/api/entities/companies/'

# %%
#biult disct for search
search_com = []
for com in companies:
    search_com.append(company_link+com)

# %%
search_com
# Out:
# ['https://www.linkedin.com/voyager/api/entities/companies/79148173',
#  'https://www.linkedin.com/voyager/api/entities/companies/18573594',
#  'https://www.linkedin.com/voyager/api/entities/companies/13455953',
#  'https://www.linkedin.com/voyager/api/entities/companies/17949672',
#  'https://www.linkedin.com/voyager/api/entities/companies/70457597',
#  'https://www.linkedin.com/voyager/api/entities/companies/75057736',
#  'https://www.linkedin.com/voyager/api/entities/companies/11211633',
#  'https://www.linkedin.com/voyager/api/entities/companies/18807806',
#  'https://www.linkedin.com/voyager/api/entities/companies/78999795',
#  'https://www.linkedin.com/voyager/api/entities/companies/47654576']

# %%
import time
time.sleep(3)

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
           }

# %%
response_dict=[]

# %%
## searchin loop
for search in search_com:
    with requests.session() as s:
        s.cookies['li_at'] = "AQEIACMHPkMvrgOYvEsAAAGDcP1DJgAAAYOVCccmTQAAAAAAAAAAADBGAiEAkKeC2zquafqzLpZ1Im6apVaD9-QCDORTvuwr7hQJpRUCIQCGhYoH0fRASHYQ1rDmDXIbrONVtu3h1BwIDGvPh66iBn7nAiXLYzCb0XOUmFxbMjQl8fVy"
        s.cookies["JSESSIONID"] = "ajax:8343847006655895677"
        s.headers = headers
        s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
        response = s.get(search)
        response_dict.append(response.json())
    time.sleep(6) #add sleep to handel request

# %%
len(response_dict)
# Out:
# 11

# %%
data=[]
for res in response_dict:
    data.append(res.values())

# %%
columns=[]
for res in response_dict:
    columns = res.keys()
    break

# %%
len(columns), len(data)
# Out:
# (10, 11)

# %%
for dat in data: 
    print(dat)
    break
# Out:
# dict_values(['11-50', ['Finance', 'Crypto ', 'Cryptocurrency', 'Investment', 'Financial Management'], 'urn:li:fs_company:79148173', 'https://www.ccgla.co.uk/', 'Public Company', {'year': 2020}, {'objectUrn': 'urn:li:company:79148173', 'trackingId': 'UFDA0yaJQfS27d8Nvw4StA=='}, ['Financial Services'], 'Cryptocurrency can be confusing, intimidating, and overwhelming. At Crypto Glasgow we provide you with knowledge, experience and community so you can make informed and responsible decisions with your investments.\n\nWe provide knowledge and insights. You soak it all up to make informed and confident investment decisions you can be proud of.\n\n25k Instagram Followers\n2000+ Facebook Followers\n2000+ Private Members Group', {'headquarters': 'Glasgow ', 'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:79148173', 'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:79148173', 'following': False, 'trackingUrn': 'urn:li:company:79148173', 'followingTyp
# ...

# %%
df = pd.DataFrame(data=data)
df
# Out:
#        0                                                  1   \
# 0   11-50  [Finance, Crypto , Cryptocurrency, Investment,...
# 1   11-50  [Finance, Crypto , Cryptocurrency, Investment,...
# 2   11-50                 [Cryptocurrency, Crypto, Exchange]
# 3   11-50  [Staffing, nft's, metaverse, talent acquisitio...
# 4   11-50  [Cybersecurity, IoT, Internet, Software, Quant...
# 5    2-10                         urn:li:fs_company:70457597
# 6    2-10     [Crypto , Blockchain, Bitcoin, CryptoCurrency]
# 7    2-10  [Blockchain, Islamic Finance, Crypto, Banking,...
# 8    2-10  [blockchain, blockchain research, blockchain i...
# 9    2-10                         urn:li:fs_company:78999795
# 10   2-10  [best exchange crypto , best crypto exchange ,...
#
#                                  2                                    3   \
# 0        urn:li:fs_company:79148173             https://www.ccgla.co.uk/
# 1        urn:li:fs_company:79148173             https://www.ccgla.co.uk/
# ...

# %%
import pandas as pd

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
           }

company_link = 'https://www.linkedin.com/voyager/api/entities/companies/47654576'

with requests.session() as s:
    s.cookies['li_at'] = "AQEIACMHPkMvrgOYvEsAAAGDcP1DJgAAAYOVCccmTQAAAAAAAAAAADBGAiEAkKeC2zquafqzLpZ1Im6apVaD9-QCDORTvuwr7hQJpRUCIQCGhYoH0fRASHYQ1rDmDXIbrONVtu3h1BwIDGvPh66iBn7nAiXLYzCb0XOUmFxbMjQl8fVy"
    s.cookies["JSESSIONID"] = "ajax:8343847006655895677"
    s.headers = headers
    s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
    response = s.get(company_link)
    response_dict = response.json()
    print(response_dict)
# Out:
# {'employeeCountRange': '2-10', 'specialties': ['best exchange crypto ', 'best crypto exchange ', 'bitmex fees', 'binance margin trading', 'bitcoin trading with leverage'], 'entityUrn': 'urn:li:fs_company:47654576', 'websiteUrl': 'https://cryptomargintrading.info/', 'companyType': 'Partnership', 'entityInfo': {'objectUrn': 'urn:li:company:47654576', 'trackingId': 'F7fPwfQDTnyxk+W94lbjMg=='}, 'industries': ['Banking'], 'description': 'Cryptomargintrading.info is a global crypto information and data website giving worldwide access to high quality, in depth and reliable information on the latest cryptocurrency pairs, coins and the best exchanges. You will find everything you need to know in the cryptocurrency worlds such as complete exchange reviews and guides and up to date trading news.', 'basicCompanyInfo': {'headquarters': 'London', 'followingInfo': {'entityUrn': 'urn:li:fs_followingInfo:urn:li:company:47654576', 'dashFollowingStateUrn': 'urn:li:fsd_followingState:urn:li:fsd_company:
# ...

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
           }

company_link = "https://www.linkedin.com/voyager/api/search/dash/clusters?decorationId=com.linkedin.voyager.dash.deco.search.SearchClusterCollection-162&origin=FACETED_SEARCH&q=all&query=(keywords:chemistry,flagshipSearchIntent:SEARCH_SRP,queryParameters:(companyHqGeo:List(101165590),resultType:List(GROUPS)),includeFiltersInResponse:false)&start=20"
with requests.session() as s:
    s.cookies['li_at'] = "AQEIACMHPkMvrgOYvEsAAAGDcP1DJgAAAYOVCccmTQAAAAAAAAAAADBGAiEAkKeC2zquafqzLpZ1Im6apVaD9-QCDORTvuwr7hQJpRUCIQCGhYoH0fRASHYQ1rDmDXIbrONVtu3h1BwIDGvPh66iBn7nAiXLYzCb0XOUmFxbMjQl8fVy"
    s.cookies["JSESSIONID"] = "ajax:8343847006655895677"
    s.headers = headers
    s.headers["csrf-token"] = s.cookies["JSESSIONID"].strip('"')
    response = s.get(company_link)
    response_dict1 = response.json()
    print(response_dict1)
# Out:
# {'metadata': {'primaryResultType': 'GROUPS', 'blockedQuery': False, 'searchId': '2812bd3e-0d3b-44c7-b863-723f9c27ce19', 'filterAppliedCount': 0, 'totalResultCount': 3015, '$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterCollectionMetadata'}, 'elements': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterViewModel', 'position': 21, 'results': [{'addEntityToSearchHistory': True, 'summary': {'textDirection': 'USER_LOCALE', '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2', 'text': 'A group for those who have or have had any affiliation with Physical Chemistry at Lund University. This could be as PhD Student, Post Doc, guest or any other collaboration. Here we will post any new information about the department and the Annual Report.', 'attributesV2': [{'start': 69, 'length': 9, '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextAttributeV2', 'detailDataUnion': {'style': 'BOLD'}}]}, 'image': {'attributes': [{'detail
# ...

# %%
response_dict1
# Out:
# {'metadata': {'primaryResultType': 'GROUPS',
#   'blockedQuery': False,
#   'searchId': '2812bd3e-0d3b-44c7-b863-723f9c27ce19',
#   'filterAppliedCount': 0,
#   'totalResultCount': 3015,
#   '$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterCollectionMetadata'},
#  'elements': [{'$recipeType': 'com.linkedin.voyager.dash.deco.search.SearchClusterViewModel',
#    'position': 21,
#    'results': [{'addEntityToSearchHistory': True,
#      'summary': {'textDirection': 'USER_LOCALE',
#       '$recipeType': 'com.linkedin.voyager.dash.deco.common.text.TextViewModelV2',
#       'text': 'A group for those who have or have had any affiliation with Physical Chemistry at Lund University. This could be as PhD Student, Post Doc, guest or any other collaboration. Here we will post any new information about the department and the Annual Report.',
#       'attributesV2': [{'start': 69,
#         'length': 9,
# ...
